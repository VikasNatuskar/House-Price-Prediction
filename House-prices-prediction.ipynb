# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
test_df = pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test_df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=[15,10])
sns.heatmap(train_df.isnull(), yticklabels=False, cbar=False)
plt.show()

# %%
train_df['LotFrontage'] = train_df['LotFrontage'].fillna(train_df['LotFrontage'].mean())

# %%
train_df.drop('Alley', axis=1, inplace=True)

# %%
train_df['FireplaceQu'].isna().sum()
# Out:
# 690

# %%
train_df['GarageType'].isna().sum()
# Out:
# 81

# %%
train_df['PoolQC'].isna().sum()
# Out:
# 1453

# %%
train_df['PoolArea'].isna().sum()
# Out:
# 0

# %%
train_df['Fence'].isna().sum()
# Out:
# 1179

# %%
train_df['MiscFeature'].isna().sum()
# Out:
# 1406

# %%
train_df.drop(['PoolQC','Fence','MiscFeature'], axis= 1, inplace=True)

# %%
train_df.drop(['FireplaceQu'], axis=1, inplace=True)

# %%
train_df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
train_df['MasVnrArea'].isna().sum()
# Out:
# 8

# %%
train_df['MasVnrArea'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
train_df['MasVnrArea'].mean()
# Out:
# 103.68526170798899

# %%
train_df['MasVnrArea'] = train_df['MasVnrArea'].fillna(train_df['MasVnrArea'].mean())

# %%
plt.figure(figsize=[15,10])
sns.heatmap(train_df.isnull(), yticklabels=False, cbar=False)
plt.show()

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
train_df['MasVnrType'].mode()
# Out:
# 0    None
# dtype: object

# %%
train_df['MasVnrType'] = train_df['MasVnrType'].fillna(train_df['MasVnrType'].mode()[0])

# %%
train_df['BsmtQual'] = train_df['BsmtQual'].fillna(train_df['BsmtQual'].mode()[0])
train_df['BsmtCond'] = train_df['BsmtCond'].fillna(train_df['BsmtCond'].mode()[0])
train_df['BsmtExposure'] = train_df['BsmtExposure'].fillna(train_df['BsmtExposure'].mode()[0])
train_df['BsmtFinType1'] = train_df['BsmtFinType1'].fillna(train_df['BsmtFinType1'].mode()[0])
train_df['BsmtFinType2'] = train_df['BsmtFinType2'].fillna(train_df['BsmtFinType2'].mode()[0])
train_df['Electrical'] = train_df['Electrical'].fillna(train_df['Electrical'].mode()[0])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
train_df['GarageType'] = train_df['GarageType'].fillna(train_df['GarageType'].mode()[0])
train_df['GarageYrBlt'] = train_df['GarageYrBlt'].fillna(train_df['GarageYrBlt'].mean())
train_df['GarageFinish'] = train_df['GarageFinish'].fillna(train_df['GarageFinish'].mode()[0])
train_df['GarageQual'] = train_df['GarageQual'].fillna(train_df['GarageQual'].mode()[0])
train_df['GarageCond'] = train_df['GarageCond'].fillna(train_df['GarageCond'].mode()[0])

# %%
plt.figure(figsize=[15,10])
sns.heatmap(train_df.isnull(), yticklabels=False, cbar=False)
plt.show()

# %%
train_df.isna().sum().sum()
# Out:
# 0

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test_df.drop(['Alley','FireplaceQu','PoolQC','Fence','MiscFeature'], axis= 1, inplace=True)

# %%
plt.figure(figsize=[15,10])
sns.heatmap(test_df.isna(), yticklabels= False, cbar=False)
plt.xticks(fontsize = 10)
plt.show()

# %%
test_df['LotFrontage'] = test_df['LotFrontage'].fillna(test_df['LotFrontage'].mean())
test_df['MasVnrArea'] = test_df['MasVnrArea'].fillna(test_df['MasVnrArea'].mean())

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
test_df['MSZoning'] = test_df['MSZoning'].fillna(test_df['MSZoning'].mode()[0])
test_df['Utilities'] = test_df['Utilities'].fillna(test_df['Utilities'].mode()[0])
test_df['Exterior1st'] = test_df['Exterior1st'].fillna(test_df['Exterior1st'].mode()[0])
test_df['Exterior2nd'] = test_df['Exterior2nd'].fillna(test_df['Exterior2nd'].mode()[0])
test_df['MasVnrType'] = test_df['MasVnrType'].fillna(test_df['MasVnrType'].mode()[0])
test_df['BsmtQual'] = test_df['BsmtQual'].fillna(test_df['BsmtQual'].mode()[0])
test_df['BsmtCond'] = test_df['BsmtCond'].fillna(test_df['BsmtCond'].mode()[0])
test_df['BsmtExposure'] = test_df['BsmtExposure'].fillna(test_df['BsmtExposure'].mode()[0])
test_df['BsmtFinType1'] = test_df['BsmtFinType1'].fillna(test_df['BsmtFinType1'].mode()[0])
test_df['BsmtFinType2'] = test_df['BsmtFinType2'].fillna(test_df['BsmtFinType2'].mode()[0])
test_df['BsmtFinSF1'] = test_df['BsmtFinSF1'].fillna(test_df['BsmtFinSF1'].mean())
test_df['BsmtFinSF2'] = test_df['BsmtFinSF2'].fillna(test_df['BsmtFinSF2'].mean())

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1459 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
test_df['BsmtUnfSF'] = test_df['BsmtUnfSF'].fillna(test_df['BsmtUnfSF'].mean())
test_df['TotalBsmtSF'] = test_df['TotalBsmtSF'].fillna(test_df['TotalBsmtSF'].mean())
test_df['BsmtFullBath'] = test_df['BsmtFullBath'].fillna(test_df['BsmtFullBath'].mean())
test_df['BsmtHalfBath'] = test_df['BsmtHalfBath'].fillna(test_df['BsmtHalfBath'].mean())
test_df['KitchenQual'] = test_df['KitchenQual'].fillna(test_df['KitchenQual'].mode()[0])
test_df['Functional'] = test_df['Functional'].fillna(test_df['Functional'].mode()[0])
test_df['GarageType'] = test_df['GarageType'].fillna(test_df['GarageType'].mode()[0])
test_df['GarageYrBlt'] = test_df['GarageYrBlt'].fillna(test_df['GarageYrBlt'].mean())
test_df['GarageFinish'] = test_df['GarageFinish'].fillna(test_df['GarageFinish'].mode()[0])
test_df['GarageCars'] = test_df['GarageCars'].fillna(test_df['GarageCars'].mean())
test_df['GarageArea'] = test_df['GarageArea'].fillna(test_df['GarageArea'].mean())
test_df['GarageQual'] = test_df['GarageQual'].fillna(test_df['GarageQual'].mode()[0])
test_df['GarageCond'] = test_df['GarageCond'].fillna(test_df['GarageCond'].mode()[0])
test_df['SaleType'] = test_df['SaleType'].fillna(test_df['SaleType'].mode()[0])

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1459 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
plt.figure(figsize=[15,10])
sns.heatmap(test_df.isna(), yticklabels=False, cbar= False)
plt.xticks(fontsize = 10)
plt.show()

# %%
test_df.isna().sum().sum()
# Out:
# 0

# %%
train_df.shape
# Out:
# (1460, 76)

# %%
test_df.shape
# Out:
# (1459, 75)

# %%
combine_data = train_df.append(test_df, ignore_index=True)

# %%
combine_data.shape
# Out:
# (2919, 76)

# %%
combine_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
combine_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 2914  2915         160       RM         21.0     1936   Pave      Reg
# 2915  2916         160       RM         21.0     1894   Pave      Reg
# 2916  2917          20       RL        160.0    20000   Pave      Reg
# 2917  2918          85       RL         62.0    10441   Pave      Reg
# 2918  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 2914         Lvl    AllPub    Inside  ...             0         0           0
# 2915         Lvl    AllPub    Inside  ...             0         0           0
# 2916         Lvl    AllPub    Inside  ...             0         0           0
# 2917         Lvl    AllPub    Inside  ...             0         0           0
# 2918         Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
combine_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
combine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2919 non-null   object
#  3   LotFrontage    2919 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %%
cat_columns = ['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1',
               'Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType',
               'ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
               'Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','GarageType','GarageFinish',
              'GarageQual','GarageCond','PavedDrive','SaleType','SaleCondition']

# %%
main_df = pd.get_dummies(data= combine_data,columns= cat_columns, drop_first=True)

# %%
main_df.shape
# Out:
# (2919, 234)

# %%
main_train_df = main_df[:1459 + 1]
main_test_df = main_df[1459 + 1:]

# %%
main_train_df.shape
# Out:
# (1460, 234)

# %%
main_test_df.shape
# Out:
# (1459, 234)

# %%
main_train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0       706.0  ...               0               0
# 1          1976         0.0       978.0  ...               0               0
# 2          2002       162.0       486.0  ...               0               0
# 3          1970         0.0       216.0  ...               0               0
# 4          2000       350.0       655.0  ...               0               0
#
# ...

# %%
main_test_df.head()
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1460  1461          20         80.0    11622            5            6
# 1461  1462          20         81.0    14267            6            6
# 1462  1463          60         74.0    13830            5            5
# 1463  1464          60         78.0     9978            6            6
# 1464  1465         120         43.0     5005            8            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# 1460       1961          1961         0.0       468.0  ...               0
# 1461       1958          1958       108.0       923.0  ...               0
# 1462       1997          1998         0.0       791.0  ...               0
# 1463       1998          1998        20.0       602.0  ...               0
# 1464       1992          1992         0.0       263.0  ...               0
#
#       SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %%
x_train = main_train_df.drop(['SalePrice'], axis=1)
y_train = main_train_df['SalePrice']

x_test = main_test_df.drop(['SalePrice'],axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_predict = lr.predict(x_test)

# %%
len(lr_predict)
# Out:
# 1459

# %%
test_val = pd.read_csv('sample_submission.csv')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
np.sqrt(mean_squared_error(y_true= test_val['SalePrice'], y_pred= lr_predict))
# Out:
# 76420.1129576542

# %%
mean_absolute_error(y_true= test_val['SalePrice'], y_pred= lr_predict)
# Out:
# 56807.42881181309

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_predict = rfr.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_true= test_val['SalePrice'], y_pred= rf_predict))
# Out:
# 70437.78519277014

# %%
mean_absolute_error(y_true= test_val['SalePrice'], y_pred= rf_predict)
# Out:
# 53726.99488595961

# %%
from xgboost import XGBRegressor

# %%
xgbr = XGBRegressor()

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgbr_predict = xgbr.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_true= test_val['SalePrice'], y_pred= xgbr_predict))
# Out:
# 72819.75710512446

# %%
mean_absolute_error(y_true= test_val['SalePrice'], y_pred= xgbr_predict)
# Out:
# 52931.053443712415

# %%
xgbr_predict
# Out:
# array([125685.875, 156787.06 , 185434.42 , ..., 173010.56 , 112065.73 ,
#        236443.34 ], dtype=float32)

# %%
test_val['SalePrice']
# Out:
# 0       169277.052498
# 1       187758.393989
# 2       183583.683570
# 3       179317.477511
# 4       150730.079977
#             ...
# 1454    167081.220949
# 1455    164788.778231
# 1456    219222.423400
# 1457    184924.279659
# 1458    187741.866657
# Name: SalePrice, Length: 1459, dtype: float64

# %%
predData = pd.DataFrame(xgbr_predict)
datasets = pd.concat([test_val['Id'], predData], axis=1)

# %%
datasets.columns = ['Id','SalePrice']

# %%
datasets.to_csv('sample_submission01.csv', index= False)

# %% [markdown]
# ### Score: 0.14576  ### Rank : 2136

# %% [markdown]
# ## Hyper - Parameter Tunning

# %%
n_estimators = [100,200,300,400,500]
max_depth = [2,3,5,10,15]
learning_rate = [0.05,0.1,0.15,0.20]
min_child_weight = [1,2,3,4]

hyperparameters = { 'n_estimators' : n_estimators,
                  'max_depth' : max_depth,
                  'learning_rate': learning_rate,
                  'min_child_weight' : min_child_weight}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
rSearchCV = RandomizedSearchCV(estimator= xgbr, param_distributions= hyperparameters, cv=5, n_iter=50)

# %%
rSearchCV.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1,
#                                           enable_categorical=False, gamma=0,
#                                           gpu_id=-1, importance_type=None,
#                                           interaction_constraints='',
#                                           learning_rate=0.300000012,
#                                           max_delta_step=0, max_depth=6,
#                                           min_child_weight=1, missing=nan,
#                                           monotone_constraints='()',
#                                           n_estimators=100, n_jobs=12,
#                                           num_parallel_tree=1, predictor='auto',
# ...

# %%
rSearchCV.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.15, max_delta_step=0,
#              max_depth=5, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
rSearchCV_predict = rSearchCV.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_true= test_val['SalePrice'], y_pred= rSearchCV_predict))
# Out:
# 74034.70750501829

# %%
mean_absolute_error(y_true= test_val['SalePrice'], y_pred= rSearchCV_predict)
# Out:
# 54881.35242790852

# %%
rSearchCV_predict
# Out:
# array([126227.875, 153783.88 , 189870.56 , ..., 179790.48 , 118061.08 ,
#        214213.31 ], dtype=float32)

# %%
xgbr_predict
# Out:
# array([125685.875, 156787.06 , 185434.42 , ..., 173010.56 , 112065.73 ,
#        236443.34 ], dtype=float32)

# %%
test_val['SalePrice']
# Out:
# 0       169277.052498
# 1       187758.393989
# 2       183583.683570
# 3       179317.477511
# 4       150730.079977
#             ...
# 1454    167081.220949
# 1455    164788.778231
# 1456    219222.423400
# 1457    184924.279659
# 1458    187741.866657
# Name: SalePrice, Length: 1459, dtype: float64

# %%
predData01 = pd.DataFrame(rSearchCV_predict)
datasets01 = pd.concat([test_val['Id'], predData01], axis=1)

# %%
datasets01.columns = ['Id','SalePrice']
datasets01.to_csv('sample_submission02.csv', index=False)

# %% [markdown]
# ### Score: 0.13567 ### Rank : 1425

# %% [markdown]
# # ANN

# %%
x_train.shape, y_train.shape, x_test.shape
# Out:
# ((1460, 233), (1460,), (1459, 233))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(units= 64, activation='relu', input_dim = 233))
model.add(Dense(units= 32, activation = 'relu'))
model.add(Dense(units= 16, activation= 'relu'))
model.add(Dense(units=1, activation = 'linear'))

# %%
model.compile(optimizer='adam', loss=tf.losses.mean_squared_error)

# %%
model.fit(x_train.values,y_train.values, validation_split= 0.20, epochs= 100, verbose=1, shuffle=True, batch_size = 32)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 1s 4ms/step - loss: 37481406464.0000 - val_loss: 36526374912.0000
# Epoch 2/100
# 37/37 [==============================] - 0s 2ms/step - loss: 30520092672.0000 - val_loss: 22850510848.0000
# Epoch 3/100
# 37/37 [==============================] - 0s 1ms/step - loss: 12877637632.0000 - val_loss: 5962753024.0000
# Epoch 4/100
# 37/37 [==============================] - 0s 2ms/step - loss: 7478203904.0000 - val_loss: 5651142144.0000
# Epoch 5/100
# 37/37 [==============================] - 0s 1ms/step - loss: 6260332032.0000 - val_loss: 5039567360.0000
# Epoch 6/100
# 37/37 [==============================] - 0s 2ms/step - loss: 5154500096.0000 - val_loss: 4733524992.0000
# Epoch 7/100
# 37/37 [==============================] - 0s 1ms/step - loss: 4538810368.0000 - val_loss: 4559583232.0000
# Epoch 8/100
# 37/37 [==============================] - 0s 2ms/step - loss: 4023998464.0000 - val_loss: 4305907200.0000
# Epoch 9/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                14976
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# ...
# Total params: 17,601
# Trainable params: 17,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann_predict = model.predict(x_test)

# %%
ann_predict
# Out:
# array([[148399.69],
#        [193696.47],
#        [186774.06],
#        ...,
#        [190992.6 ],
#        [ 99864.02],
#        [226024.31]], dtype=float32)

# %%
predData03 = pd.DataFrame(ann_predict)
Dataset = pd.concat([test_val['SalePrice'], predData03], axis=1)

# %%
Dataset.columns = ['Id','SalePrice']
Dataset.to_csv('sample_submission04.csv', index=False)

# %%
x_train.corr()
# Out:
#                              Id  MSSubClass  LotFrontage   LotArea  \
# Id                     1.000000    0.011156    -0.009601 -0.033226
# MSSubClass             0.011156    1.000000    -0.357056 -0.139781
# LotFrontage           -0.009601   -0.357056     1.000000  0.306795
# LotArea               -0.033226   -0.139781     0.306795  1.000000
# OverallQual           -0.028365    0.032628     0.234196  0.105806
# ...                         ...         ...          ...       ...
# SaleCondition_AdjLand -0.034852    0.016241    -0.037020 -0.013208
# SaleCondition_Alloca  -0.009018    0.030002    -0.018090  0.008966
# SaleCondition_Family   0.004865    0.000983     0.015818 -0.010781
# SaleCondition_Normal   0.015881    0.024359    -0.072074  0.005711
# SaleCondition_Partial -0.020738   -0.051068     0.124842  0.022635
#
#                        OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id                       -0.028365     0.012609  -0.012713     -0.021998
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=[15,10])
sns.heatmap(x_train.corr())
plt.show()

# %%
np.sqrt(mean_squared_error(y_true= test_val['SalePrice'], y_pred=ann_predict))
# Out:
# 63625.92290743569

# %%
mean_absolute_error(y_true= test_val['SalePrice'], y_pred=ann_predict)
# Out:
# 47021.6329118124

# %% [markdown]
# ## ANN Hyper-Parameter Tunning

# %%
from hyperas import optim
from hyperopt import tpe

# %%
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %%
msle = MeanSquaredLogarithmicError()

# %%
def build_model(hp):
    model = Sequential()
    hp_units1 = hp.Int('units1', min_value = 32, max_value = 512, step = 32)
    hp_units2 = hp.Int('units2', min_value = 32, max_value = 512, step = 32)
    hp_units3 = hp.Int('units3', min_value = 32, max_value = 512, step = 32)
    model.add(Dense(units= hp_units1, activation='relu'))
    model.add(Dense(units= hp_units2, activation='relu'))
    model.add(Dense(units= hp_units3, activation='relu'))
    model.add(Dense(units=1, activation='linear'))
    
    hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate= hp_learning_rate), loss=msle, metrics=[msle])
    return model

# %%
tuner = kt.RandomSearch(build_model, objective='val_mean_squared_logarithmic_error',max_trials=10)

# %%
tuner.search(x_train, y_train, epochs = 10, validation_data = (x_test, test_val['SalePrice']), validation_split = 0.2)
# Out:
# Trial 10 Complete [00h 00m 01s]
# val_mean_squared_logarithmic_error: 7.505725860595703
#
# Best val_mean_squared_logarithmic_error So Far: 0.05291375517845154
# Total elapsed time: 00h 00m 18s
# INFO:tensorflow:Oracle triggered exit

# %%
best_model = tuner.get_best_models()[0]

# %%
best_model.build(x_train.shape)
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (1460, 352)               82368
#
#  dense_1 (Dense)             (1460, 320)               112960
#
#  dense_2 (Dense)             (1460, 416)               133536
#
#  dense_3 (Dense)             (1460, 1)                 417
#
# ...
# Total params: 329,281
# Trainable params: 329,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.fit(x_train, y_train, epochs=1000, validation_data=(x_test, test_val['SalePrice']), batch_size = 64, validation_split=0.2)
# Out:
# Epoch 1/1000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0108 - mean_squared_logarithmic_error: 0.0107 - val_loss: 0.0284 - val_mean_squared_logarithmic_error: 0.0272
# Epoch 2/1000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0120 - mean_squared_logarithmic_error: 0.0119 - val_loss: 0.0273 - val_mean_squared_logarithmic_error: 0.0260
# Epoch 3/1000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0112 - mean_squared_logarithmic_error: 0.0110 - val_loss: 0.0274 - val_mean_squared_logarithmic_error: 0.0262
# Epoch 4/1000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0114 - mean_squared_logarithmic_error: 0.0114 - val_loss: 0.0273 - val_mean_squared_logarithmic_error: 0.0262
# Epoch 5/1000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0108 - mean_squared_logarithmic_error: 0.0105 - val_loss: 0.0271 - val_mean_squared_logarithmic_error: 0.0260
# Epoch 6/1000
# ...

# %%
pred_ = best_model.predict(x_test)

# %%
pred_
# Out:
# array([[121187.98 ],
#        [155720.47 ],
#        [183810.62 ],
#        ...,
#        [207801.81 ],
#        [ 82967.875],
#        [218764.08 ]], dtype=float32)

# %%
test_val['SalePrice']
# Out:
# 0       169277.052498
# 1       187758.393989
# 2       183583.683570
# 3       179317.477511
# 4       150730.079977
#             ...
# 1454    167081.220949
# 1455    164788.778231
# 1456    219222.423400
# 1457    184924.279659
# 1458    187741.866657
# Name: SalePrice, Length: 1459, dtype: float64

# %%
np.sqrt(mean_squared_error(y_true= test_val['SalePrice'], y_pred= pred_))
# Out:
# 72415.65093452329

# %%
mean_absolute_error(y_true= test_val['SalePrice'], y_pred=pred_)
# Out:
# 55552.841667158245

# %%
predData05 = pd.DataFrame(pred_)
dataset05 = pd.concat([test_val['Id'], predData05], axis=1)

# %%
dataset05.columns = ['Id','SalePrice']
dataset05.to_csv('sample_submission05.csv', index=False)
